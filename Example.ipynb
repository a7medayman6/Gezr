# %%
from ArStem import ArabicStemmer
stemmer = ArabicStemmer()

# %%
from ArStem import ArabicStemmer
stemmer = ArabicStemmer()
words = [ "استوصف", "اتبع", "تبعية", "المُستصغَرون", "فاستضعفناهُما", "أفاستسقيناكموها", "وليتلطف", "تجربة", "مخطئ", "أرشد", "الرَحمن", "مرحبا", "ركعة", "فاسقيناكموها", "ارتقب"]
stemmed, df = stemmer.stem(' '.join(words), verbose=True)
df
# Out:
#              Tokens Normalized Tokens Def Articles Removed Suffex Removed  \
# 0            استوصف            استوصف                ستوصف          ستوصف
# 1              اتبع              اتبع                  تبع            تبع
# 2             تبعية             تبعية                تبعية            تبع
# 3        المستصغرون        المستصغرون             مستصغرون         مستصغر
# 4      فاستضعفناهما      فاستضعفناهما         فاستضعفناهما        فاستضعف
# 5   أفاستسقيناكموها   افاستسقيناكموها       فاستسقيناكموها        فاستسقي
# 6           وليتلطف           وليتلطف              وليتلطف        وليتلطف
# 7             تجربة             تجربة                تجربة          تجربة
# 8              مخطئ              مخطا                 مخطا           مخطا
# 9              أرشد              ارشد                  رشد            رشد
# 10           الرحمن            الرحمن                 رحمن           رحمن
# 11            مرحبا             مرحبا                مرحبا          مرحبا
# 12             ركعة              ركعة                 ركعة           ركعة
# 13     فاسقيناكموها      فاسقيناكموها         فاسقيناكموها          فاسقي
# 14            ارتقب             ارتقب                 رتقب           رتقب
#
#    Prefex Removed Last Suffex Removed  Root
# 0             وصف                 وصف   وصف
# 1             تبع                 تبع   تبع
# 2             تبع                 تبع   تبع
# 3             صغر                 صغر   صغر
# 4             ضعف                 ضعف   ضعف
# 5             سقي                 سقي   سقي
# 6             لطف                 لطف   لطف
# 7            جربة                 جرب   جرب
# 8             خطا                 خطا   خطا
# 9             رشد                 رشد   رشد
# 10           رحمن                 رحم   رحم
# 11           رحبا                 رحب   رحب
# 12           ركعة                 ركع   ركع
# 13            سقي                 سقي   سقي
# 14           رتقب                رتقب  رتقب

# %%
from ArStem import ArabicStemmer
stemmer = ArabicStemmer()
words = [ "تزحلق", "مزركش", "تمركز", "يتمرجح", "تزعزع", "زعزع", "هَرولة", "مهندس", "تَمنطق", 
            "جمهورية", "جُمهور", "مُطلسم", "ترجمان", "ترجمة", "مُترجم", "عجرفة", "متعجرف"]
stemmed, df = stemmer.stem(' '.join(words), verbose=True)
df
# Out:
#      Tokens Normalized Tokens Def Articles Removed Suffex Removed  \
# 0     تزحلق             تزحلق                تزحلق          تزحلق
# 1     مزركش             مزركش                مزركش          مزركش
# 2     تمركز             تمركز                تمركز          تمركز
# 3    يتمرجح            يتمرجح               يتمرجح         يتمرجح
# 4     تزعزع             تزعزع                تزعزع          تزعزع
# 5      زعزع              زعزع                 زعزع           زعزع
# 6     هرولة             هرولة                هرولة          هرولة
# 7     مهندس             مهندس                مهندس          مهندس
# 8     تمنطق             تمنطق                تمنطق          تمنطق
# 9   جمهورية           جمهورية              جمهورية          جمهور
# 10    جمهور             جمهور                جمهور          جمهور
# 11    مطلسم             مطلسم                مطلسم          مطلسم
# 12   ترجمان            ترجمان               ترجمان           ترجم
# 13    ترجمة             ترجمة                ترجمة          ترجمة
# 14    مترجم             مترجم                مترجم          مترجم
# 15    عجرفة             عجرفة                عجرفة          عجرفة
# 16   متعجرف            متعجرف               متعجرف         متعجرف
#
#    Prefex Removed Last Suffex Removed   Root
# 0            زحلق                زحلق   زحلق
# 1            زركش                زركش   زركش
# 2             ركز                 ركز    ركز
# 3             رجح                 رجح    رجح
# 4            زعزع                زعزع   زعزع
# 5            زعزع                زعزع   زعزع
# 6           هرولة                هرول   هرول
# 7            هندس                هندس   هندس
# 8             نطق                 نطق    نطق
# 9           جمهور               جمهور  جمهور
# 10          جمهور               جمهور  جمهور
# 11           طلسم                طلسم   طلسم
# 12           ترجم                ترجم   ترجم
# 13           رجمة                 رجم    رجم
# 14            رجم                 رجم    رجم
# 15          عجرفة                عجرف   عجرف
# 16           عجرف                عجرف   عجرف
